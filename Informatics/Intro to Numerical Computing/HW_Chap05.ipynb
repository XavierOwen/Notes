# %% [markdown]
# # HW05: Gaussian elimination, LU factorization, Cholesky factorization
# **Yuanxing Cheng, 810925466**
# ## Q1
# $Answer$
#
# $Code$
#
#     clear
#     clc
#
#     epsilon = eps;
#
#     N = [10 100 1000];
#
#     cout = ['\n for n = %d, the relative error norm is %.8e; \n' ...
#         'the relative componentwise error is %.8e; \n' ...
#         'and the accuracy upper bond is %.8e. \n'];
#
#     for i = 1:3
#
#         n = N(i);
#         x_true = (1:n).';
#
#         M = 2 * rand(n) - 1;
#         for j = 1:n
#             M(j,j) = 1;
#         end
#
#         b = M * x_true;
#
#         x = M \ b;
#
#         relErr = norm(x - x_true, inf) / norm(x_true, inf);
#         relErr_componentwise = max( abs( (x - x_true)./ x_true ) );
#         accUpper = cond(M,inf)*n*eps;
#
#         fprintf(cout,n,relErr,relErr_componentwise,accUpper);
#     end
#
# $Output$
#
# ```
#
#  for n = 10, the relative error norm is 5.50670620e-15;
# the relative componentwise error is 2.88657986e-14;
# and the accuracy upper bond is 1.87844432e-12.
#
#  for n = 100, the relative error norm is 7.71649411e-14;
# the relative componentwise error is 1.94303832e-12;
# and the accuracy upper bond is 2.43552686e-10.
#
#  for n = 1000, the relative error norm is 3.95516508e-13;
# the relative componentwise error is 5.32187627e-11;
# and the accuracy upper bond is 2.10065852e-08.
# ```
#
# # Q2
# $Answer$
#
# $Code$
#
# ```
# clear
# clc
#
# epsilon = eps;
#
# N = [10 100 1000];
#
# cout = ['\n for n = %d, the relative error norm is %.8e; \n' ...
#     'the relative componentwise error is %.8e; \n' ...
#     'and the accuracy upper bond is %.8e. \n'];
#
# for i = 1:3
#
#     n = N(i);
#     x_true = (1:n).';
#
#     M = rand(n);
#
#     b = M * x_true;
#
#     x = M \ b;
#
#     relErr = norm(x - x_true, inf) / norm(x_true, inf);
#     relErr_componentwise = max( abs( (x - x_true)./ x_true ) );
#     accUpper = cond(M,inf)*n*eps;
#
#     fprintf(cout,n,relErr,relErr_componentwise,accUpper);
# end
#
# ```
#
# $Output$
#
# ```
#
#  for n = 10, the relative error norm is 1.31450406e-14;
# the relative componentwise error is 4.70734562e-14;
# and the accuracy upper bond is 1.32457878e-12.
#
#  for n = 100, the relative error norm is 2.39275266e-13;
# the relative componentwise error is 8.73390249e-12;
# and the accuracy upper bond is 2.53714080e-10.
#
#  for n = 1000, the relative error norm is 5.31191517e-11;
# the relative componentwise error is 3.72320730e-09;
# and the accuracy upper bond is 5.47731208e-07.
# ```
#
# # Q3
# $Answer$
#
# $Code$
# ```
# clear
# clc
#
# epsilon = eps;
#
# N = [5 10 15];
#
# cout = ['\n for n = %d, the relative error norm is %.8e; \n' ...
#     'the relative componentwise error is %.8e; \n' ...
#     'and the accuracy upper bond is %.8e. \n'];
#
# for i = 1:3
#
#     n = N(i);
#     x_true = (1:n).';
#
#     M = hilb(n);
#
#     b = M * x_true;
#
#     x = M \ b;
#
#     relErr = norm(x - x_true, inf) / norm(x_true, inf);
#     relErr_componentwise = max( abs( (x - x_true)./ x_true ) );
#     accUpper = cond(M,inf)*n*eps;
#
#     fprintf(cout,n,relErr,relErr_componentwise,accUpper);
# end
# ```
#
# $Output$
# ```
#
#  for n = 5, the relative error norm is 4.01234601e-12;
# the relative componentwise error is 5.01543251e-12;
# and the accuracy upper bond is 1.04766862e-09.
#
#  for n = 10, the relative error norm is 2.68628065e-05;
# the relative componentwise error is 3.68417434e-05;
# and the accuracy upper bond is 7.84979493e-02.
# > In HW05c (line 21)
# Warning: Matrix is close to singular or badly scaled. Results may be inaccurate. RCOND
# =  5.460912e-19.
# Warning: Matrix is close to singular or badly scaled. Results may be inaccurate. RCOND
# =  8.269626e-19.
# > In cond (line 46)
#   In HW05c (line 25)
#
#  for n = 15, the relative error norm is 6.65937744e-01;
# the relative componentwise error is 1.10156035e+00;
# and the accuracy upper bond is 4.02759351e+03.
# ```
