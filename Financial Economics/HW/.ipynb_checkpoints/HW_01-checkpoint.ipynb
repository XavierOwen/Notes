# %% [markdown]
# # <center>Financial Economics HW_01</center>
#
# **<center>11510691 程远星$\DeclareMathOperator*{\argmin}{argmin}
# \DeclareMathOperator*{\argmax}{argmax}
# \newcommand{\using}[1]{\stackrel{\mathrm{#1}}{=}}
# \newcommand{\ffrac}{\displaystyle \frac}
# \newcommand{\space}{\text{ }}
# \newcommand{\bspace}{\;\;\;\;}
# \newcommand{\QQQ}{\boxed{?\:}}
# \newcommand{\void}{\left.\right.}
# \newcommand{\CB}[1]{\left\{ #1 \right\}}
# \newcommand{\SB}[1]{\left[ #1 \right]}
# \newcommand{\P}[1]{\left( #1 \right)}
# \newcommand{\dd}{\mathrm{d}}
# \newcommand{\Tran}[1]{{#1}^{\mathrm{T}}}
# \newcommand{\d}[1]{\displaystyle{#1}}
# \newcommand{\EE}[2][\,\!]{\mathbb{E}_{#1}\left[#2\right]}
# \newcommand{\Var}[2][\,\!]{\mathrm{Var}_{#1}\left[#2\right]}
# \newcommand{\Cov}[2][\,\!]{\mathrm{Cov}_{#1}\left(#2\right)}
# \newcommand{\Corr}[2][\,\!]{\mathrm{Corr}_{#1}\left(#2\right)}
# \newcommand{\I}[1]{\mathrm{I}\left( #1 \right)}
# \newcommand{\N}[1]{\mathrm{N} \left( #1 \right)}
# \newcommand{\ow}{\text{otherwise}}\void^\dagger$</center>**

# %% [markdown]
# ## Question 2.1
#
# $\bspace$Firstly they share the same domian $c \in \mathbb{R}_+^{N}$, and the range, $\mathbb{R}$. Then we consider two comsumption plans $a,b \in \mathbb{R}_+^{N}$. Suppose that $a \succsim b$, then from the definition of utility function $U$ we have $a \succsim b \Leftrightarrow U\P{a} \geq U\P{b}$, such that $V\P{a} = f\P{U\P{a}} \geq f\P{U\P{b}} = V\P{b}$

# %% [markdown]
# ## Question 2.2
#
# $\P{1}$ instatiability
#
# $\bspace$Suppose there're two possible consumption plan $c_i = \SB{c_{0,i};c_{1a,i};c_{1b,i}}, i=1,2$ and let $c_1 \geq c_2$ meaning that $c_{0,1} \geq c_{0,2}$ and $c_{1a,1} \geq c_{1a,2}$ and $c_{1b,1} \geq c_{1b,2}$. Then for the first Utility function,
#
# $$U\P{c_1} = \log c_{0,1} + \ffrac{1} {2} \P{\log c_{1a,1} + \log c_{1b,1}} \geq \log c_{0,12} + \ffrac{1} {2} \P{\log c_{1a,2} + \log c_{1b,2}} = U\P{c_2} $$
#
# $\bspace$And for the second one, when $1-\gamma > 0$, $\ffrac{1} {1-\gamma}x^{1-\gamma}$ is an increasing function on $x \geq 0$ and when $1-\gamma < 0$, $\ffrac{1} {1-\gamma}x^{1-\gamma}$ is still an increasing function on $x \geq 0$. Thus
#
# $$U\P{c_1} = \ffrac{1} {1-\gamma}c_{0,1}^{1-\gamma} + \ffrac{1} {2} \P{\ffrac{1} {1-\gamma}c_{1a,1}^{1-\gamma} + \ffrac{1} {1-\gamma}c_{1b,1}^{1-\gamma}} \geq \ffrac{1} {1-\gamma}c_{0,2}^{1-\gamma} + \ffrac{1} {2} \P{\ffrac{1} {1-\gamma}c_{1a,2}^{1-\gamma} + \ffrac{1} {1-\gamma}c_{1b,2}^{1-\gamma}} = U\P{c_2} $$
#
# $\bspace$For the third one, when $\alpha > 0$, $-e^{-\alpha x}$ is an increasing function on $x \geq 0$, however it turns to decreasing when $\alpha < 0$ which fails the instatiability. So one possible solution is to let $U\P{c} = -\alpha e^{-\alpha c_{\void_0}}-\ffrac{\alpha} {2} \P{e^{-\alpha c_{\void_{1a}}} + e^{-\alpha c_{\void_{1b}}}}$. Then we can easily prove that $U\P{c_1} \geq U\P{c_2}$. But to prove the convexity, we'd better assume that $\alpha > 0$.
#
# $\P{2}$ continuity
#
# $\bspace$Consider a series of consumption plan $\CB{c_{i}}, i=1,2,\cdots$ with a limit $\lim\limits_{n \to \infty} c_n= c_{\cdot}$ meaning that $\lim\limits_{n \to \infty} c_{j,n}= c_{j}$ for $j = 0,1a,1b$. For the first utility function, by the property of $\log$ function, we have $\lim\limits_{n \to \infty} \log c_{j,n} = \log \P{ \lim\limits_{n \to \infty} c_{j,n}} = \log c_{j}$ and thus we have their linear combination $\lim\limits_{n \to \infty}U\P{c_n} = U\P{c}$
#
# $\bspace$For the second and third one, since $\ffrac{1} {1-\gamma}x^{1-\gamma}$ and $-e^{-\alpha x}$ are continuous on the domain, we can use the same method to draw the conclusion.
#
# $\P{3}$ convexity
#
# $\bspace$Suppose that $U\P{c_1} \geq U\P{c_2}$, and let $\beta \in \P{0,1}$, then for the first utility function, since $\log$ funciton is convex, we have
#
# $$\begin{align}
# U\P{\beta c_1 + \P{1-\beta}c_2} &= \log\P{\beta c_{\void_{0,1}} + \P{1-\beta}c_{\void_{0,2}}\,} +\ffrac{1} {2}\SB{ \log \P{\beta c_{\void_{1a,1}} + \P{1-\beta}c_{\void_{1a,2}}\,} + \log \P{\beta c_{\void_{1b,1}} + \P{1-\beta}c_{\void_{1b,2}}\,}} \\
# & \geq \beta \P{\log c_{\void_{0,1}} + \ffrac{1} {2}\log c_{\void_{1a,1}} + \ffrac{1} {2}\log c_{\void_{1b,1}}} + \P{1-\beta} \P{ \log c_{\void_{0,2}} + \ffrac{1} {2}\log c_{\void_{1a,2}} + \ffrac{1} {2}\log c_{\void_{1b,2}}} \\
# &= \beta U\P{c_1} + \P{1-\beta}U\P{c_2} \geq U\P{c_2}
# \end{align}$$
#
# $\bspace$Similarly, for the next two utility functions, $\P{\ffrac{1} {1-\gamma}x^{1-\gamma}}'' = -\ffrac{1} {\gamma}x^{-\gamma - 1} < 0$ and $\P{-e^{-\alpha x}}'' = -\alpha^2 e^{-\alpha x} <0$, thus all three are convex and we can prove the convexity for the later two utility functions.

# %% [markdown]
# ## Question 2.4
#
# $\P{1}$
#
# $\bspace$Since $\Omega = 3$ we have the payoff space: $\mathbb{R}^3$.
#
# $\P{2}$
#
# $$X \equiv \SB{X_{\cdot,1},X_{\cdot,2}} = \begin{bmatrix}
# 1 & 1 \\
# 1 & 2 \\
# 1 & 3
# \end{bmatrix}$$
#
# $\P{3}$
#
# $\bspace$The payoff vector is $X\begin{bmatrix}
# \theta_1 \\
# \theta_2
# \end{bmatrix} = \begin{bmatrix}
# \theta_1 + \theta_2 \\
# \theta_1 + 2\theta_2 \\
# \theta_1 + 3\theta_2
# \end{bmatrix}$. And the price is $\SB{S_1,S_2}\begin{bmatrix}
# \theta_1 \\
# \theta_2
# \end{bmatrix} = S_1\theta_1 + S_2 \theta_2$
#
# $\P{4}$
#
# $\bspace$The market portfolio is $\d{\sum_{k=1}^{K}}\begin{bmatrix}
# 1 \\
# 2
# \end{bmatrix} =  \begin{bmatrix}
# K \\
# 2K
# \end{bmatrix}$. Its payoff vector is $\begin{bmatrix}
# K + 2K \\
# K + 2\times 2K \\
# K + 3\times 2K
# \end{bmatrix} = \begin{bmatrix}
# 3K \\
# 5K \\
# 7K
# \end{bmatrix}$ and the overall price is $\SB{S_1,S_2}\begin{bmatrix}
# K \\
# 2K
# \end{bmatrix} = \P{S_1 + 2S_2}K$.
#
# $\P{5}$
#
# $\bspace$Since there're only two securities thus $N=2$. Denote $\theta = \begin{bmatrix}
# \theta_1 \\
# \theta_2
# \end{bmatrix} \in \mathbb{R}^2$ then we have the marketed payoff $M = \CB{Y =X\theta: \theta \in \mathbb{R}^2}$
#
# $\P{6}$
#
# $\bspace$When shorting is not allowed, the domain of $\theta$ is limited to the first quadrant and thus $M = \CB{Y =X\theta: \theta \in \mathbb{R}_+^2}$
#
# $\P{7}$
#
# $$X = \begin{bmatrix}
# 1 & 1 & 0 \\
# 1 & 2 & 0 \\
# 1 & 3 & 1
# \end{bmatrix}, \theta = \begin{bmatrix}
# \theta_1 \\
# \theta_2 \\
# \theta_3
# \end{bmatrix} \in \mathbb{R}^3$$
#
# thus the new marketed payoff is $M = \CB{Y =X\theta: \theta \in \mathbb{R}^3}$

# %% [markdown]
# ## Question 2.7
#
# $\P{1}$
#
# $\bspace$Without trading his consumption plan can only be $\SB{100,1}$ thus $U^a = \log 100 + \rho \log 1 = \log 100$
#
# $\P{2.1}$
#
# $\bspace$His budget set is $B\P{\begin{bmatrix}
# 100\\
# 1
# \end{bmatrix}, \CB{[1+r_F],[1]}} = \CB{c \geq 0: c_0 = 100 - \theta, c_1 = 1 + \theta\P{1 + r_F}, \theta \in \mathbb{R}}$. His current wealth is (from the formula in the next chapter!) $w = e_0 + \Tran\phi e_1 = 100 + \phi_1 \times 1 = 100 + \ffrac{1} {1+r_F}$.
#
# $\P{2.2}$
#
# $\bspace$The optimization problem now is
#
# $$
# \begin{array}{cl}
# \d{\max_{\theta}} & U^b\P{c} = \log\P{100 - \theta} + \rho \log\P{1 + \theta\P{1 + r_F}} \\
# s.t. & c_0 = 100 - \theta, c_1 = 1 + \theta\P{1 + r_F} \\
# & c_0,c_1 \geq 0
# \end{array}
# $$
#
# $\bspace$We don't need lagrangian multipliers😂😂😂. It's obvious that $\ffrac{\partial^2 U^b\P{c}} {\partial \theta^2} = -\ffrac{1} {\P{\theta - 100}^2} - \ffrac{\rho\P{1+r_F}^2} {\P{1+\theta\P{1+r_F}}^2} < 0$ thus letting its first order partial derivative equal to zero gives $\ffrac{\partial U^b\P{c}} {\partial \theta} = \ffrac{1} {\theta - 100} + \ffrac{\rho \P{1+r_F}} {1 + \theta\P{1+r_F}} = 0$. Solve the equation and we can obtain the optimized saving, which is just the number of the security you're going to hold here:
#
# $$s = \theta = \ffrac{100\rho \P{1+r_F} - 1} {\P{1+\rho}\P{1+r_F}}\\
# c_0 = 100 - \ffrac{100\rho \P{1+r_F} - 1} {\P{1+\rho}\P{1+r_F}} = \ffrac{100\P{1+r_F} + 1} {\P{1+\rho}\P{1+r_F}} = \ffrac{1} {1+\rho} w\\
# c_1 = 1 + \ffrac{100\rho \P{1+r_F} - 1} {\P{1+\rho}} = \rho\ffrac{100\P{1+r_F}+1}{1+\rho} = \ffrac{\rho\P{1+r_F}} {1+\rho}w \\[0.8em]
# U^b\P{c} = \log\P{\ffrac{w} {1+\rho}} + \rho\log\P{\ffrac{\rho\P{1+r_F}} {1+\rho}w}
# $$
#
# $\P{2.3}$
#
# $\bspace$Since we already have the expression for $\theta$, we can see that it will rise with the rise of $r_F$. And assuming $\rho >0$, we have the same conclusion that it will rise with the rise of $\rho$.
#
# $\P{3}$
#
# $\bspace$$U^a\P{c}$ is just the case when $\rho \P{1+r_F} = 0.01$ thus since $U^b\P{c}$ is the optimized solution it's obvious $U^b\P{c} \geq U^a\P{c}$.
#
# $\P{4}$
#
# $\bspace U^b\P{w-g} = \log\P{\ffrac{w-g} {1+\rho}} + \rho\log\P{\ffrac{\rho\P{1+r_F}} {1+\rho}\P{w-g}} = \log 100 \Rightarrow g = w - \P{1+\rho}\P{\ffrac{100} {\rho^{\rho}\P{1+r_F}^{\rho}}}^{\ffrac{1} {1+\rho}}$
#
# $\bspace$Obviously it increases with $r_F$. As for $\rho$, well, to find its derivative is way too complicated! So intuitively, we can see that when $\rho$ increases, the agents will intend to spend more in the period of time $1$. Therefore they will have more money in their account and thus gain more in security market, leading to a higher $g$.

# %% [markdown]
# ## Question 3.1
#
# $\P{1}$
#
# $\bspace$There're only $2$ states in time period $1$ thus there're only two possible securities in the Arrow-Debreu Market. And their payoff vectors are $\SB{1;0}$ and $\SB{0;1}$ respectively.
#
# $\P{2}$
#
# $\bspace$Obviously we have $e = \begin{bmatrix}
# 2 \\
# 1
# \end{bmatrix} = 2\begin{bmatrix}
# 1 \\
# 0
# \end{bmatrix} + \begin{bmatrix}
# 0 \\
# 1
# \end{bmatrix} = 2X_a + X_b$
#
# $\P{3}$
#
# $\bspace$His financial wealth is $w = 0 + [\phi_a,\phi_b]\begin{bmatrix}
# 2 \\
# 1
# \end{bmatrix} = 2\phi_a + \phi_b$. His budget plan is $B\P{\begin{bmatrix}
# 0 \\
# 2 \\
# 1
# \end{bmatrix}, \CB{\begin{bmatrix}
# 1 & 0 \\
# 0 & 1
# \end{bmatrix},S}}$, which is $\CB{c \geq 0 : \Tran{\hat\phi}c = [1,\phi_a,\phi_b]\begin{bmatrix}
# c_0 \\
# c_{1a} \\
# c_{1b}
# \end{bmatrix} =c_0 + \phi_a c_{1a} + \phi_bc_{1b} = w }$
#
# $\P{4}$
#
# $\bspace$His optimization problem can be written as
#
# $$\begin{array}{cl}
# \d{\max_{c\in C}} & U\P{c}=-e^{-c_{\void_0}}-\ffrac{1}{2}\P{e^{-c_{\void_{1a}}}+e^{-c_{\void_{1b}}}} \\
# s.t. & 2\phi_a + \phi_b = w = c_0 + \phi_a c_{1a} + \phi_bc_{1b}
# \end{array}$$
#
# $\bspace$Using the lagrangian multiplier method we have
#
# $$\begin{array}{l}
# \partial_iU = \lambda\phi_i + \mu_i \Rightarrow \begin{cases}
# e^{-c_{\void_0}} = \lambda \times 1 + \mu_0 \\
# 0.5 e^{-c_{\void_{1a}}} = \lambda \phi_{a} + \mu_a \\
# 0.5 e^{-c_{\void_{1b}}} = \lambda \phi_{b} + \mu_b
# \end{cases} \\
# \Tran{\hat\phi}\P{e-c} = \P{2-c_{1a}}\phi_a + \P{1-c_{1b}}\phi_b - c_0 = 0 \\
# \mu_i c_i = 0
# \end{array}$$
#
# $\bspace$Notice that $\text DU \gg 0$, we can assume that $\mu_i = 0$. Thus, we can plug in $\begin{cases}
# c_0 = -\log \lambda \\
# c_{1a} = -\log\P{2\phi_a \lambda} \\
# c_{1b} = -\log\P{2\phi_b \lambda}
# \end{cases}$
#
# $$\big(2 + \log\P{2\phi_a\lambda}\big)\phi_a + \big(1 + \log\P{x\phi_b\lambda}\big)\phi_b + \log\lambda = 0 \\
# \log \lambda = -\ffrac{ 2\phi_a + \phi_b + \phi_a\P{\log 2\phi_a} + \phi_b\P{\log 2\phi_b} } {1 + \phi_a + \phi_b}$$
#
# $\bspace$Thus we can find all optimized solution for $c$:
#
# $$c_0 = \ffrac{ 2\phi_a + \phi_b + \phi_a\P{\log 2\phi_a} + \phi_b\P{\log 2\phi_b} } {1 + \phi_a + \phi_b} \\
# c_{1a} =\ffrac{ 2\phi_a + \phi_b + \phi_b\P{\log 2\phi_b} - \phi_b\P{\log 2\phi_a} - \log\P{2\phi_a} } {1 + \phi_a + \phi_b} \\
# c_{1b} =\ffrac{ 2\phi_a + \phi_b + \phi_a\P{\log 2\phi_a} - \phi_a\P{\log 2\phi_b} - \log\P{2\phi_b} } {1 + \phi_a + \phi_b}
# $$
#
# $\P{5}$
#
# $\bspace$We can draw the $c-\phi$ graph to see how $\phi$ gonna affect the consumption (it's too complicated to find their derivatives). And we can find that
#
# - when $\phi_a$ increase from about $0$
#     - $c_0$ first decrease a little bit then increase
#     - $c_{1a}$ first decrease then increase
#     - $c_{1b}$ keep increasing
# - when $\phi_b$ increase from about $0$
#     - $c_0$ first decrease a little bit then increase
#     - $c_{1a}$ first decrease a little bit then increase
#     - $c_{1b}$ first decrease then keep increasing, but just a little bit
#
# $\P{6}$
#
# $\bspace$Suppoes $\phi_a = \phi_b = x$, then $c_0 = \ffrac{3x+2x\log\P{2x}} {1+2x} < 0 \Leftrightarrow \log 2x < -1.5$. Thus we can assign the value $\ffrac{e^{-2}} {2} = x$ and then $c_0 =-\ffrac{1} {2\P{e^{2} + 1}}$

# %% [markdown]
# ## Question 3.2
#
# $\P{1}$
#
# $\bspace$This is the same with **Question 2.7.2** where we find the answer should be $\theta = s = \ffrac{100\rho \P{1+r_F} - 1} {\P{1+\rho}\P{1+r_F}}$ and therefore
#
# $$c_0 = \ffrac{100\P{1+r_F} + 1} {\P{1+\rho}\P{1+r_F}},
# c_1 = \rho\ffrac{100\P{1+r_F}+1}{1+\rho}$$
#
# $\P{2}$
#
# $\bspace$To reach the market clearing, it requires
#
# $$\begin{cases}
# 100 - \theta = 100 \\
# 1 + \theta\P{1+r_F} = 1
# \end{cases} \Rightarrow \theta = 0$$
#
# $\P{3}$
#
# $\bspace$After $\theta = 0$, we have $0 = \ffrac{100\rho \P{1+r_F} - 1} {\P{1+\rho}\P{1+r_F}} \Rightarrow r_F = \ffrac{1} {100\rho} - 1$
#
# $\P{4}$
#
# $\bspace$The equilibrium interest rate $r_F$ decreases with the increase of $\rho$. It happens because when $\rho$ increases, agents will prefer spend more in the future thus there'll be more savings which leads to a lower $r_F$.

# %% [markdown]
# ## Question 3.3
#
# $\P{1}$
#
# $$\begin{array}{cl}
# \d{\max_{c_{\void_2} \in C}} & U_2 \P{c_2} = \log c_{2,0} + \rho\log c_{2,1} \\
# s.t. & c_{2,0} + \phi_a c_{2,1} = 1 + 100\phi_a \\
# & \phi_a = \P{1 + r_F}^{-1} \\
# & c_{2,0}, c_{2,1} \geq 0
# \end{array}$$
#
# solve this we'll obtain $c_{2,0}=\ffrac{1+r_F+100} {\P{1+\rho}\P{1+r_F}}, c_{2,1} = \ffrac{\rho\P{1+r_F+100}} {1+\rho}, s = 1 - c_{2,0} = \ffrac{\rho\P{1+r_F}-100} {\P{1+\rho}\P{1+r_F}}$
#
# $\P{2}$
#
# $\bspace$They are identical in terms of their wealth. $c_0 = \ffrac{w} {1+\rho}, c_1 = \ffrac{w\rho\P{1 + r_F}} {1+\rho}, s = \ffrac{e_0\rho - e_1/\P{1+r_F}} {1+\rho}$.
#
# $\P{3}$
#
# $\bspace$The market equilibrium now is
#
# $$\begin{cases}
# \ffrac{101+\ffrac{101} {1+r_F}} {1+\rho} = 101 \\
# \ffrac{\rho\P{1+r_F}\P{101 + \ffrac{101} {1+r_F}}} {1+\rho} = 101
# \end{cases} \Longrightarrow \rho\P{1+r_F} = 1$$
#
# $\P{4}$
#
# $\bspace$From the last question we can see that $r_F = \ffrac{1} {\rho} - 1$. They are different because of the different $\sum\limits_k e_{0,k}$ and $\sum\limits_k e_{1,k}$
#
# $\P{5}$
#
# $\bspace$We only need to check whether they reach the equilibrium.
#
# $$\ffrac{\partial_1 U_1\P{c_{1}}} {\partial_0 U_1\P{c_{1}}} = \ffrac{\ffrac{\rho} {c_{1,1}}} {\ffrac{1} {c_{1,0}}} = \ffrac{1} {1+r_F} \\
# \ffrac{\partial_1 U_2\P{c_{2}}} {\partial_0 U_2\P{c_{2}}} = \ffrac{\ffrac{\rho} {c_{2,1}}} {\ffrac{1} {c_{2,0}}} = \ffrac{1} {1+r_F} = \ffrac{\partial_1 U_1\P{c_{1}}} {\partial_0 U_1\P{c_{1}}}
# $$
#
# $\bspace$Thus they reached the equilibrium and thus by $Theorem.4$, this allocation is parato dominant.

# %% [markdown]
# ## Question 3.4
#
# $\P{1}$
#
# $$\begin{array}{cl}
# \d{\max_{c_{\void_{i}}\in C}} & U\P{c_i} = -\ffrac{1} {c_{i,0}} -\ffrac{1} {3}\P{\ffrac{1} {c_{i,1a}} + \ffrac{1} {c_{i,1b}} + \ffrac{1} {c_{i,1c}}}, i = 1,2 \\
# s.t. & c_{1,0} + \Tran{\phi}_1\begin{bmatrix}
# c_{1,1a}\\
# c_{1,1b}\\
# c_{1,1c}
# \end{bmatrix} = 100, c_{2,0} + \Tran{\phi}_2\begin{bmatrix}
# c_{2,1a}\\
# c_{2,1b}\\
# c_{2,1c}
# \end{bmatrix} = 0 + \Tran{\phi}_2\begin{bmatrix}
# 200\\
# 100\\
# 50
# \end{bmatrix}\\
# & c_{i,\cdot} \geq 0
# \end{array}$$
#
# $\bspace$This is a easy one, the solutions are:
#
# $$c_{1,0} = \ffrac{100} {1+\d{\sum_{a,b,c}}\P{\sqrt{\ffrac{\phi_{1,a}} {3}}}}, c_{1,\,j} = \ffrac{100} {\sqrt{3\phi_{1,\,j}}\SB{1+\d{\sum_{a,b,c}}\P{\sqrt{\ffrac{\phi_{1,a}} {3}}}}},j = 1a,1b,1c \\
# c_{2,0} = \ffrac{200\phi_{2,1a} + 100\phi_{2,1b} + 50\phi_{2,1c}} {1+\d{\sum_{a,b,c}}\P{\sqrt{\ffrac{\phi_{2,a}} {3}}}}, c_{2,\,j} = \ffrac{200\phi_{2,1a} + 100\phi_{2,1b} + 50\phi_{2,1c}} {\sqrt{3\phi_{2,\,j}}\SB{1+\d{\sum_{a,b,c}}\P{\sqrt{\ffrac{\phi_{2,a}} {3}}}}},j = 1a,1b,1c
# $$
#
# $\P{2}$
#
# $\bspace$We have the equation set: $\ffrac{100} {\sqrt{3\phi_{1,\,j}}\SB{1+\d{\sum_{a,b,c}}\P{\sqrt{\ffrac{\phi_{1,a}} {3}}}}} + \ffrac{200\phi_{2,1a} + 100\phi_{2,1b} + 50\phi_{2,1c}} {\sqrt{3\phi_{2,\,j}}\SB{1+\d{\sum_{a,b,c}}\P{\sqrt{\ffrac{\phi_{2,a}} {3}}}}} = e_{2,\,j},j = 1a,1b,1c$
#
# $\bspace$Solve the equation set we have the state price $\phi = \SB{\ffrac{1} {12}; \ffrac{1} {3};\ffrac{4} {3}}$
#
# $\P{3}$
#
# $\bspace$The result is obvious since the endowment is in the position of numerator of the expression for their consumption, like the "$100$" and "$[200;100;50]$". When they increase, the numerator $100$ and $\Tran\phi [200;100;50]$ increase.
#
# $\P{4}$
#
# $\bspace c_{k,1a}:c_{k,1b}:c_{k,1c} = \sqrt{\ffrac{1} {\phi_a}} : \sqrt{\ffrac{1} {\phi_b}} : \sqrt{\ffrac{1} {\phi_c}} = 4:2:1,k = 1,2$, that's it.
