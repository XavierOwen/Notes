# %% [markdown]
# # Investments: Background and Issues
# **Investment**
# Commitment of *current* resources in the expectation of deriving greater resources in the future.
# An investment is the commistment of *current money* or other resources in the expectation of reaping *future benefit*.
#
# ## Real Assets Versus Financial Assets
# **Real Assets**
# Assets used to produce goods and services.
# >**e.g.**
# >the land, buildings, equipment, knowledge,
#
# **Financial Assets**
# Claims on real assets or the income generated by them.
# >**e.g.**
# >stocks, bonds and derivatives
#
# $\odot$
# Real assets generate net income to economy. Financial assets simply define the allocation of income or wealth among investors.$\square$
#
# $\odot$
# If we aggregate over all balance sheets, all claims cancel out, leaving only real assets as the net wealth of the economy. National wealth consists of structures, equipment, inventoriesof goods, and land.$\square$
#
# ## Financial Assets
# **Fixes-income (debt)securities**
# Pay a specified cash flow over a specific period.
# 1. Money market
#   - short term
#   - highly marketable
#   - low risk
# >**e.g.**
# >- Treasury bills (T-bills)
# >- bank certificates of deposit (CDs)
#
# 2. Capital market (Bond market)
#   - long-term securities
# >**e.g.**
# >- Treasury bonds
# >- bonds issured by federal agencies, state and local municipalities, and corporations.
#
# **Equity**
# Common stocks, an ownership share in a corporation.
#
# **Derivative securities**
# Securities providing payoffs that depend on the values of other assets, such as *options*, *futures*, *swaps互换信贷*.
# $\odot$
# - to hedge risks or transfer them to other parties
# - to take speculative positions$\square$
#
# ## Financial Markets and the Economy
# - The information role of financial markets
# $\odot$
# stock prices can allocate capital in market economies, direct capital to the firms, and other applications with the greatest perceived potential$\square$
#
# - Consuption timing
# $\odot$
# financial markets allow individuals to separate decisions concerning *current consumption* from constraints that otherwise would be imposed by *current earning*.$\square$
#
# - Allocation of risk
# $\odot$
# allow risk adverse to bear the risk, less risk-tolerant individual can stay on the sideline$\square$
#
# - Seperation of ownership and management
# Amounts of shareholders elect a board of directors that hire and supervise the management of the firm.
# $\odot$
# Owners and managers of the firm are differnet parties$\square$
#
# **agency problem**: Conflicts of interest between managers and stockholders.
# To solve this,
# 1. Tie the income of managers to the success of the firm
# 2. Force out management teams
# 2. outsiders such as security analysts and large institutional investors suah as mutual funds or pension funds monitor the firm.
#
# - Corporate governance and corporate ethics
# $\odot$
# Markets need to be transparent for investors to make informed decisions about allocating capitals efficiently.$\square$
#
# ## The Investment Process
# **Asset allocation**: allocation of an investment portofolio across broad asset classes.
# - stocks
# - bonds
# - real estate
# - commodities
#
# **Security selection**: choice of specific securities within each asset class.
# - IBM
# - Dell
# - Apple...
#
# **Security analysis**: analysis of the value of particular securities that might be included in the portfolio.
# 决定买之前分析一下
#
# $\odot$
# The asset allocation decision is the primary determinant of a portfolio’s return.$\square$
#
# - Top-down portfolio management: from rucial asset allocation decisions to the decision of the particular securities.
# - Bottom-up strategy: portofolio is constructed from the securities with attractively price.
#
# ## Markets are Competitive
# No-free-lunch proposition:
# - **Risk-Return Trade-Off**: Assets with higher expected returns entail greater risk.
# - Efficient Markets: we can rarely expect to find bargains in the security markets.
#
# $Hypothesis$
# Financial markets process all available information about securities quickly and efficiently.
# $i.e.$
# The security price usually reflects all the information availale to investors concerning the value of the security.
#
# $\odot$
# Anytime, the security price equals the market consensus estimate of the value of the security. No underpriced or overpriced securities.$\square$
#
# **Passive management**: Buying and holding a *diversified portfolio分散化投资组合* without attempting to identify mispriced securities.
# $i.e.$
# without spending effort attempting to improve investment performance, through security analysis.
#
# **Active management**: Attempting to identify mispriced securities or to forecast broad market trends.
#
# $\odot$
# If the efficient market hypothesis were taken to the extreme, there would be no point in active security analysis. But prices would eventually depart from "correc" values, creating new incentives for experts to move in.$\square$
#
# ## The Players
# - *Firms*: net borrowers, net demanders of capital.
#   1. They raise capital now to pay for investments in plant and equipment
#   2. The income provides the returns to investors who purchase the securities.
# - *Households*: net lenders, suppliers of capital.
#   1. purchase the securities issued by firms that need to raise funds.
# - *Governments*: either borrowers or lenders, depending on the relationship between *tax revenue税收* and *government expenditures财政预算*.
#
# ### Financial Intermediaries
# **Financial intermediaries**: Institutions that "connect" borrowers and lenders by accepting funds from lenders and loaning funds to borrowers.
# $\odot$
# Both of its assets and their liabilities are almost financial.$\square$
#
# >**e.g.**
# > commercial/investment companies, mutual/hedge/pension funds, insurance companies, credit unions信用合作社
# > 1. Pooling the resources of many small investors
# > 2. Lend considerable sums to large borrowers
# > 3. Achieve significant diversification
# > 4. Accept loans that individually might be too risky
#
# **Investment companies**: Firms managing funds for investors. An investment company may manage several mutual funds.
# 1. Large-scale trading and portfolio management, the participating investors are assigned a prorated share according to the size of their investment. And its advantages let small investors pay for via a management fee to the mutual fund operator.
# 2. Design portfolio for large investors with particular goals.
#
# $\odot$
# 1. Mutual funds are sold in retail market, but hedge funds only open to institutional investors such as pension funds, endowment funds.
# 2. Mutual funds charge a fixed percentage of assets under management, but hedge funds keep a portion of trading profits as part of their fees.$\square$
#
# $\odot$
# Leverage ratio: total assets divided by bank capital.$\square$
#
# **Investment bankers**: Firms specializing in the sale of new securities to the public, typically by underwriting the issue.
#
# **Primary market**: Market for new issues of securities.
# Here the banks are called *underwriters*.
#
# **Secondary market**: Previously issued securities are traded among investors.
#
# **Venture capital** (VC): Money invested to finance a new firm.
#
# **Private equity**: Investments in companies that are not traded on a stock exchange.
#
# ## The Financial Crisis of 2008
# **Securitization**: Pooling loans into standardized securities backed by those loans, which can then be traded like any other security.
#
# >**e.g.**
# >*pass-throughs* process:
# > 1. *Homeowners* borrow money from the *originators*.
# > 2. The originators sell the mortagage to the *agency* (such as, Freddie Mac or Fannie Mae).
# > 3. The agency pool the loans into mortagage-backed securities and sell them to the final *investors*.
#
# **Systemic risk**: Risk of breakdown in the financial system, particularly due to spillover effects from one market into others.

# %% [markdown]
# ***
# ## Others
# ### Summary
# - Real assets create wealth. Financial assets represent claims to parts or all of that wealth. Financial assets determine how the ownership of real assets is distributed among investors.
# - Financial assets can be categorized as fixed-income (debt), equity, or derivative instruments. Top-down portfolio construction techniques start with the asset allocation decision—the allocation of funds across broad asset classes—and then progress to more specific security-selection decisions.
# - Competition in financial markets leads to a risk-return trade-off, in which securities that offer higher expected rates of return also impose greater risks on investors. The presence of risk, however, implies that actual returns can differ considerably from expected returns at the beginning of the investment period. Competition among security analysts also results in financial markets that are nearly informationally efficient, meaning that prices reflect all available information concerning the value of the security. Passive investment strategies may make sense in nearly efficient markets.
# - Financial intermediaries pool investor funds and invest them. Their services are in demand because small investors cannot efficiently gather information, diversify, and monitor portfolios. The financial intermediary, in contrast, is a large investor that can take advantage of scale economies.
# - Investment banking brings efficiency to corporate fund raising. Investment bankers develop expertise in pricing new issues and in marketing them to investors. By the end of 2008, all the major stand-alone U.S. investment banks had been absorbed into commercial banks or had reorganized themselves into bank holding companies. In Europe, where universal banking had never been prohibited, large banks had long maintained both commercial and investment banking divisions.
# - The financial crisis of 2008 showed the importance of systemic risk. Systemic risk can be limited by transparency that allows traders and investors to assess the risk of their counterparties, capital requirements to prevent trading participants from being brought down by potential losses, frequent settlement of gains or losses to prevent losses from accumulating beyond an institution's ability to bear them, incentives to discourage excessive risk taking, and accurate and unbiased analysis by those charged with evaluating security risk.
#
# ### Key terms
# - active management
# - agency problems
# - asset allocation
# - derivative securities
# - equity
# - financial assets
# - financial intermediaries
# - fixed-income (debt) securities
# - investment
# - investment bankers
# - investment companies
# - passive management
# - primary market
# - private equity
# - real assets, 3risk-return trade-off
# - secondary market
# - securitization
# - security analysis
# - security selection
# - systemic risk
# - venture capital (VC)

# %% [markdown]
# ## Assignment
# 1. Financial assets represent ***over 60%*** of total assets of U.S. households.
# 2. *Asset allocation* refers to ***the allocation of the investment portfolio across broad asset classes***.
# 3. *Security selection* refers to the ***choice of specific securities within each asset class***.
# 4. ***Production equipment*** is real assets; while *Bonds*, *Stocks*, *Commercial paper* are not.
# 5. Commodity and derivative markets allow firms to adjust their ***exposure to various business risks***.
# 6. ***a real estate brokerage firm*** is **not** a financial intermediary; whil *mutual fund*, *insurance company*, *a savings and loan company* are.
# 7. Accounting scandals can often be attributed to a particular concept in the study of finance known as the ***agency problem***.
# 8. The inability of shareholders to influence the decisions of managers, despite overwhelming shareholder support, is a breakdown in ***Corporate governance*** mechanism.
# 9. A major cause of mortgage market meltdown in 2007 and 2008 was linked to ***securitization***, not *private equity investments*, *negative analyst recommendations*, *online trading*.
# 10. The systemic risk that led to the financial crisis of 2008 was increased by ***collateralized debt obligations***, ***subprime mortgages***, ***credit default swaps***.
