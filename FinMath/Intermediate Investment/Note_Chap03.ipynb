# %% [markdown]
# # Security markets
# ## How firms issue securities
# They can raise funds either by borrowing money or by selling shares in the firm.
#
# **Primary market**: Market for new issues of securities.
#
# **Secondary market**: Market for already-existing securities.
#
# Shares of *publicly listed* firms trade continually on well-known markets such as the New York Stock Exchange, also called *publicly traded*, *publicly owned*, or just *public companies*.There any investor can choose to buy shares for his or her portfolio. While *private corporations*, are whose shares are held by small numbers of managers and investors. The ownership stakes in the firm are still determined in proportion to share ownership, but those shares do not trade in public exchanges.
#
# ### Privately Held Firms
# A privately held company is owned by a *relatively small number of shareholders*. Privately held firms have fewer obligations to release financial statements and other information to the public. This saves money and frees the firm from disclosing information that might be helpful to its competitors.
#
# **Private placement**: Primary offerings in which shares are sold directly to a small group of institutional or wealthy investors.
#
# When private firms wish to raise funds, they sell shares directly to a small number of institutional or wealthy investors in a private placement.
# - Attractiveness
# **Rule 144A of the SEC** allows them to make these placements without preparing the extensive and costly registration statements required of a public company.
# - Drawback
#   1. Shares in privately held firms **do not trade in secondary markets** such as a stock exchange, and this greatly reduces their **liquidity** and presumably reduces the prices that investors will pay for them.
#   *Liquidity refers to the ability to trade an asset at a fair price on short notice. Investors demand price concessions to buy illiquid securities.*
#   2. Privately held firms were allowed to have only up to 499 shareholders. This limited their ability to raise large amounts of capital from a wide base of investors.
#   *Actually, almost all of the largest companies in the U.S. have been public corporations.*
#
# ### Publicly Traded Companies
# Firms can *go public* if they wish to raise capital from a wide range of investors. They will sell its securities to the general public and allow them to freely trade in established securities markets.
#
# **initial public offering (IPO)**: First public sale of stock by a formerly private company.
# Later, the firm may go back to the public and issue additional shares. A seasoned equity offering is the sale of additional shares in firms that already are publicly traded. For example, a sale by Apple of new shares of stock would be considered a seasoned new issue.
#
# **Seasoned equity offering**: the sale of additional shares in firms that already are publicly traded.
#
# **underwriters**: Underwriters purchase securities from the issuing company and resell them to the public.
# Usually a lead firm forms an underwriting syndicate of other investment bankers to share the responsibility for the stock issue.
#
# **prospectus**: A description of the firm and the security it is issuing.
# A preliminary registration statement must be filed with the *Securities and Exchange Commission* (SEC), describing the issue and the prospects of the company. And prospectus is its final version. And at this point, the price at which the securities will be offered to the public is announced.
#
# **Firm commitment**: The investment bankers purchase the securities from the issuing company and then resell them to the public. The issuing firm sells the securities to the underwriting syndicate for the public offering price **less a spread** that serves as compensation to the underwriters.
# In addition to the spread, the investment banker also may receive shares of common stock or other securities of the firm.
#
# ### Shelf Registration
# In **1982** when the SEC approved **Rule 415**, which allows firms to register securities and gradually sell them to the public for two years following the initial registration.
# 1. They can be sold on short notice, with little additional paperwork, because they are already registered.
# 2. They can be sold in small amounts without incurring substantial flotation costs.
# 3. The securities are “on the shelf,” *ready to be issued*.
#
# >**Check**
# >Why does it make sense for shelf registration to be limited in time?
# >
# Limited-time shelf registration was introduced because of its favorable trade-off of saving issue costs versus providing disclosure. Allowing unlimited shelf registration would circumvent “blue sky” laws that ensure proper disclosure as the financial circumstances of the firm change over time.
#
# ### Initial Public Offering (IPO)
# Investment bankers manage the issuance of new securities to the public.
#
# 1. SEC commented on the registration statement and a preliminary prospectus then was distributed to interested investors
# 2. the investment bankers organize ***road shows*** in which they travel around the country to publicize the imminent offering. The $purpose$ are:
#   - generate interest among potential investors and provide information about the offering.
#   - provide information to the issuing firm and its underwriters about the price at which they will be able to market the securities.
# 3. Large investors communicate their interest in purchasing shares of the IPO to the underwriters; these indications of interest are called a ***book*** and the process of polling potential investors is called ***bookbuilding***.
# *The book provides valuable information to the issuing firm because institutional investors often will have useful insights about both the market demand for the security as well as the prospects of the firm and its competitors.*
# 4. Investment bankers will commonly revise both their initial estimates of the offering price of a security and the number of shares offered based on feedback from the investing community.
#
# $\dagger$
# Other than leader underwriter, the investment bankers are also underwriters.
#
# IPOs commonly are **underpriced** compared to the price at which they could be marketed.
# 1. If a firm wishes to get a large allocation when it is optimistic about the security, it needs to reveal its optimism.
# 2. The underwriter needs to offer the security at a bargain price to these investors to induce them to participate in bookbuilding and share their information.
#
# $\odot$
# Despite their typically attractive first-day returns, IPOs have been poor long-term investments. Other IPOs cannot even be fully sold to the market. Underwriters left with unmarketable securities are forced to sell them at a loss on the secondary market. Therefore, the investment banker bears the price risk of an underwritten issue.$\square$
#
# ## How securities are traded
# ### Types of Markets
# - Direct search markets
#    1. the least organized market.
#    2. Buyers and sellers must seek each other out directly.
#    3. sporadic participation and nonstandard goods.
#    >**e.g.**
#    >sale of a used refrigerator on Craigslist
# - Brokered markets
#   1. The next level of organization
#   2. In markets where trading in a good is active, brokers find it profitable to offer search services to buyers and sellers.
#   3. Brokers in particular markets develop specialized knowledge on valuing assets traded in that market.
#   >**e.g.**
#   >1. Real estate market, where economies of scale in searches for available homes and for prospective buyers make it worthwhile for participants to pay brokers to conduct the searches.
#   >2. Primary market, where new issues of securities are offered to the public, is an example of a brokered market.
# - **Dealer markets**: in which traders specializing in particular assets buy and sell for their own accounts.
#   1. When trading activity in a particular type of asset increases, this market arise and get more organized.
#   2. Dealers purchase these assets for their own accounts, and later sell them for a profit from their inventory.
#   3. The spreads between dealers’ buy (or “bid”) prices and sell (or “ask”) prices are a source of profit.
#   4. Dealer markets save traders on search costs because market participants can easily look up the prices at which they can buy from or sell to dealers.
#   5. A fair amount of market activity is required
#   6. Most bonds trade in over-the-counter dealer markets.
# - **Auction markets**: A market where all traders meet at one place to buy or sell an asset.
#   1. An advantage of auction markets over dealer markets is that one need not search across dealers to find the best price for a good. If all participants converge, they can arrive at mutually agreeable prices and save the bid–ask spread.
#   2. Both over-the-counter dealer markets and stock exchanges are *secondary markets*. They are organized for investors to trade existing securities among themselves.
#
# $\odot$
# More and more organized, and Brokered Market is primary market; Dealer Market and Auction Market are secondary market.$\square$
#
# >**e.g.**
# >1. *NASDAQ*: Computer-linked priced quotation system for the OTC market. **A Dealer market**.
# >2. *NYSE*: Investors → Brokerage Firms → Floor broker → Specialist. **Auction market**
# >3. *Electronic Communication Network*: Computer networks that allow direct trading without market makers. **Direct Search market**
#
# >**e.g.**
# >
# >1. Used cars trade in dealer markets (used-car lots or auto dealerships) and in direct search markets when individuals advertise in local newspapers or on websites.
# >2. Paintings trade in broker markets when clients commission brokers to buy or sell art for them, in dealer markets at art galleries, and in auction markets.
# 3. Rare coins trade in dealer markets, for example, in coin shops or shows, but they also trade in auctions and in direct search markets when individuals advertise they want to buy or sell coins.
#
# ### Types of Orders
# Broadly speaking, there are two types of orders: market orders and orders contingent on price.
#
# - **Market orders**: buy or sell orders that are to be executed immediately at current market prices.
#   1. **Bid Price**: The price at which a dealer or other trader is willing to purchase a security.
#   2. **Ask Price**: The price at which a dealer or other trader will sell a security.
#   3. **Bid-Ask Spread**: The difference between the bid and asked prices.
#   >**e.g.**
#   >Investor might call her broker and ask for the market price of Facebook. The broker might report back that the best bid price is \$76.40 and the best ask price is \$76.42, meaning that the investor would need to pay \$76.42 to purchase a share and could receive \$76.40 a share if she wished to sell some of her own holdings of Facebook.
#   4. posted price quotes actually represent commitments to trade up to a specified number of shares. If the market order is for more than this number of shares, the order may be filled at multiple prices. And we call **Depth** as the the total number of shares offered for trading at the best bid and ask prices.
#   $\dagger$
#   If you want to purchase more than the dealer offered, the excess number of shares will be charged higher than the asked price.
#   $\odot$
#   Depth is considered another component of liquidity.$\square$
#   5. Another trader may beat our investor to the quote, meaning that her order would then be executed at a worse price.
#   $\dagger$
#   Beat means her offer a higher price to do the trade and then, your willing to buy, is lost.
# - Price-contingent orders
#   - **Limit buy (sell) order**: An order specifying a price at which an investor is willing to buy or sell a security.
#   $\odot$
#     1. Limit buy order: instruct the broker to buy some number of shares if and when they may be obtained **at** or **below** a stipulated price.
#     2. Limit sell order: instruct the broker to sell if and when the stock price rises **above** a specified limit.
#   $\dagger$
#   Actually, **at** that *limit price* is also OK.
#   - *Limit order book*: A collection of limit orders waiting to be executed.
#   >
#   >**e.g.** A limit order book
#   >
#   >$$\begin{array}{c|c}
# \text{Bid} & \text{Ask} \\ \hline
# \text{Price (Size)} & \text{Price (Size)} \\ \hline
#  76.40 (600) & 76.42 (400)  \\
#  76.39 (900) & 76.43 (600)  \\
#  76.38 (817) & 76.44 (700)  \\
#  76.37 (964) & 76.45 (1,300)  \\
# \end{array}$$
#   >
#   >The best orders are at the top of the list, called the *inside quotes*, the highest buy and lowest sell orders from the dealer. However, that order sizes at the *inside quotes* can be fairly small. Therefore, investors interested in larger trades face an *effective* spread greater than the nominal one since they cannot execute their entire trades at the inside price quotes.
#
#     $\dagger$
#     1. Limit price must be reasonable, or the order may never be executed.
#     2. You can set up an end day of that order like the order is good till the end of the day, good the end of 90 days or good until cancelled.
#   - **Stop buy (sell) order**: Trade is not to be executed unless stock hits a price limit.
#     1. stop-loss orders: sell the stock if its price falls **below** a stipulated level
#     2. stop-buy orders: buy when its price rises **above** a limit.
# ***
# About **short sales**
#
# Purpose:  to profit from a decline in the price of a stock or security.
#
# About *Margin Trading*: a way of leverage that magnify your gains or losses.
#
# Mechanics:
# 1. Borrow stock through a broker (stock is your liability now)
# 2. Sell it and deposit proceeds and a margin in an account
# 3. Closing out the position: buy the stock and return to the party who lent you the stock
#
# But before doing that, Short sellers are required to post margin (cash) with the  broker to cover losses in case the stock goes up in price during the short sale and the sellers can't pay the losses. Here's how we calculate them
#
# $$\boxed{\text{Margin} = \frac{\text{Investor's net worth, or equity value}} {\text{Market value of the securities}} = \frac{\text{Your money}} {\text{Stock market value}} }$$
#
# $\dagger$
# Larger margin, then you make more money with same cost.
#
# **Initial margin** (IM): The minimum acceptable level of equity when the securities are purchased (per transaction), and at least 50% should be paid in cash (by FED regulation), however typically 60%. Denote assets as $A$, liabilitiew as $L$ and equity as $E$, we can get the formula:
#
# $$\text{IM} = \frac{A_0 - L_0} {A_0} = \frac{E_0} {A_0}$$
#
# **Maintenance margin** (MM): The minimum level of equity position (net worth) during the life of the loan. At least 25% for NYSE-traded securities, however typically 30%.
#
# $$\text{MM} = \frac{A_1 - L_1} {A_1} = \frac{E_1} {A_1}$$
#
# And when your MM falls below this level, say the stock price goes down, the investor receives a **Margin Call** from his broker, requiring him to deposit cash or sell his stock.
#
# >**e.g.** about marginal trading
# > If $\text{IM} = 50\%$, stock price is $20$.
# >
# >|                | Invested money | Shares | Stock market value | Price goes up for 10% | Return rate $r$|
# |:--------------:|:--------------:|:------:|:------------------:|:---------------------:|:-----------:|
# |  Cash account  |      1000      |   50   |        1000        |          1100         |     10%     |
# | Margin account |      1000      |   100  |        2000        |          2200         |     20%     |
# > $\dagger$
# >
# >$$\text{IM} \times \frac{r_{\text{margin}}} {r_{\text{cash}}} = 1$$
# >
# >$$\begin{array}{|c|c|}
# \text{Assets} & \text{Liabilities \& Equity} \\ \hline
# \text{Stocks} = 2000 & \text{Borrowed} = 1000  \\ \hline
# & \text{Equity} = 1000
# \end{array}
# \;\xrightarrow{\text{Price goes down to 15}}\;
# \begin{array}{|c|c|}
# \text{Assets} & \text{Liabilities \& Equity} \\ \hline
# \text{Stocks} = 1500 & \text{Borrowed} = 1000  \\ \hline
# & \text{Equity} = 500
# \end{array} $$
# >
# >Then if the price goes down to $15$, and the MM is set as 30%. Then you have to do something to let the ratio of Equity to Asset reach that number, either deposit more, or sell some stocks. 😂😂😂 Actually your margin has became $500/1500 = 1/3$ now, and your return is $(500-1000)/1000 = -50\%$.
# >
# >We can actually calculate the lowest price that you are still safe.
# >
# >$$\text{MM} = \frac{\text{Number of shares} \times \text{Price} - \text{Borrowed}}{\text{Number of shares} \times \text{Price}} = \frac{\text{Number of shares} \times \text{Price} - \text{Number of shares} \times \text{Original Price} \times \left( 1 - \text{IM} \right)}{\text{Number of shares} \times \text{Price}} \Rightarrow \boxed{\text{Least price} =  \frac{\text{Borrowed}}{\text{Number of shares} \times \left( 1 - \text{MM} \right)} = \text{Original Price} \times \frac{ 1 - \text{IM}}{ 1 - \text{MM} }}$$
# >
# >$$\text{Least price} = 20 \cdot \frac{50\%} {70\%}$$
# >
#
# >**e.g.** about short sale
# >
# >| Price | Shares borrowed | Initial margin | Maintenance margin |
# |:-----:|:---------------:|:-------------:|:------------------:|
# |  100 |       100       |      50%      |         30%        |
# >
# >$$\begin{array}{|c|c|}
# \hline
# \text{Sales Proceeds} = 10000 & \text{Stocks Owed} = 10000 \\ \hline
# \text{Initial Margin} = 5000 & \text{Equity} = 5000  \\ \hline
# \end{array}
# \;\xrightarrow{\text{Price goes up to 110}}\;
# \begin{array}{|c|c|}
# \hline
# \text{Sales Proceeds} = 10000 & \text{Stocks Owed} = 11000 \\ \hline
# \text{Initial Margin} = 5000 & \text{Equity} = 4000  \\ \hline
# \end{array} $$
# >
# >Your margin now has became $4000/11000 = 4/11$, and your return is $(4000-5000)/5000 = -20\%$, or calculate this way: $(100-110)/(100 \times 50 \%)$
# >
# >We can actually calculate the highest price that you are still safe.
# >
# >$$\text{MM} = \frac{\text{Initial Margin} + \text{Sale Proceed} - \text{Stocks Owed}}{\text{Stocks Owed}} = \frac{\text{IM} \times \text{Original Price} \times \text{Number of shares} + \text{Original Price} \times \text{Number of shares}}{\text{Price} \times \text{Number of shares}} - 1 = \frac{\left( 1 + \text{IM} \right) \times \text{Original Price}}{\text{Price}} - 1
# \Rightarrow \boxed{\text{Highest price} = \text{Original Price} \times \frac{ 1 + \text{IM}}{ 1 + \text{MM} }\,}$$
# >
# >$$\text{Highest price} =  100 \cdot \frac{1 + 0.5} {1 + 0.3}$$
# ***
# $\dagger$
# About the two e.g., Assume no interest on the margin account, and no dividends paid on the stock.
#
# ### Trading Mechanisms
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 1. An investor place an order or buying or selling with a brokerage firm.
# 2. The broker charges a commission for arranging the trade on the client’s behalf.
# 3. Brokers have several avenues by which they can execute that trade, that is, *find a buyer or seller and arrange for the shares to be exchanged.*
#
# Three trading system:
# 1. over-the-counter dealer markets
# 2. electronic communication networks
# 3. specialist markets
#
# **over-the-counter (OTC) market**: An informal network of brokers and dealers who negotiate sales of securities.
# 1. Thousands of brokers register with the SEC as security dealers. Dealers quote prices at which they are willing to buy or sell securities. A broker then executes a trade by contacting a dealer listing an attractive quote.
# 2. Before 1971, all OTC quotations were recorded *manually* and published daily on so-called *pink sheets*.
# 3. In 1971, the *National Association of Securities Dealers introduced its Automatic Quotations System*, to link brokers and dealers in a computer network where price quotes could be displayed and revised. That is **NASDAQ**, the original NASDAQ
# 4. NASDAQ was more of a price quotation system than a trading system after development. While dealers still post bid and ask prices over the network, what is now called the ***NASDAQ Stock Market***: The computer-linked price quotation and trade execution system, which allows for electronic execution of trades at quoted prices without the need for direct negotiation, and the vast majority of trades are executed electronically.
#
# **electronic communication networks (ECNs)**: Computer networks that allow direct trading without the need for market makers.
#
# Allow participants to post market and limit orders over computer networks.
# 1. The limit order book is available to all participants. Orders that can be “crossed,” that is, matched against another order, are done so automatically without requiring the intervention of a broker.
#   >**e.g.**
#   > An order to buy a share *at* a price of \$76 or *lower* will be immediately executed if there is an outstanding asked price of \$76
#   >$\odot$
#   >ECNs are true trading systems, not merely price quotation systems.$\square$
#
# 2. Trades are automatically crossed at a modest cost, typically less than a penny per share, instead of a bid-ask price.
# 3. The speed with which a trade can be executed is attractive
# 4. Considerable anonymity are offered to the investors.
#
# **Specialist markets**
# 1. In these systems, exchanges such as the NYSE (The New York Stock Exchange) assign responsibility for managing the trading in *each security* to a **specialist**. Brokers wishing to buy or sell shares for their clients direct the trade to the specialist’s post on the floor of the exchange. While each security is assigned to only one specialist, each specialist firm makes a market in many securities.
# **specialist**: A trader who makes a market in the shares of one or more firms and who maintains a “fair and orderly market” by dealing personally in the market.
# 2. The specialist maintains the limit order book of all outstanding unexecuted limit orders. When orders can be executed at market prices, the specialist executes or “crosses” the trade. The highest outstanding bid price and the lowest outstanding ask price “win” the trade.
# 3. Specialists are also mandated to maintain a “fair and orderly” market when the book of limit buy and sell orders is so thin that the spread between the highest bid price and lowest ask price becomes *too wide*. In this case, the specialist firm would be expected to offer to buy and sell shares from its own inventory at a *narrower* bid–ask spread. In this role, the specialist serves as a dealer in the stock and provides liquidity to other traders.
# $\odot$
# Liquidity providers here are those who stand willing to buy securities from or sell securities to other traders.$\square$
#
# ## The Rise of Electronic Trading
# 1. New regulations allowed brokers to compete for business, broke the hold that dealers once had on information about best-available bid and ask prices, forced integration of markets, and allowed securities to trade in ever-smaller price increments (called tick sizes).
# 2. just stop here
#
# ## Summary
# 1. Firms issue securities to raise the capital necessary to finance their investments. Investment bankers market these securities to the public on the primary market. Investment bankers generally act as underwriters who purchase the securities from the firm and resell them to the public at a markup. Before the securities may be sold to the public, the firm must publish an SEC-approved prospectus that provides information on the firm’s prospects.
# 2. Already-issued securities are traded on the secondary market, that is, in organized stock markets, or, primarily for bonds, on the over-the-counter market. Brokerage firms holding licenses to trade on an exchange sell their services to individuals, charging commissions for executing trades on their behalf.
# 3. Trading may take place in dealer markets, via electronic communication networks, or in specialist markets. In dealer markets, security dealers post bid and ask prices at which they are willing to trade. Brokers for individuals execute trades at the best available prices. In electronic markets, the existing book of limit orders provides the terms at which trades can be executed. Mutually agreeable offers to buy or sell securities are automatically crossed by the computer system operating the market. In specialist markets, the specialist acts to maintain an orderly market with price continuity. Specialists maintain a limit order book but also sell from or buy for their own inventories of stock.
# 4. NASDAQ was traditionally a dealer market in which a network of dealers negotiated directly over sales of securities. The NYSE was traditionally a specialist market. In recent years, however, both exchanges dramatically increased their commitment to electronic and automated trading. The overwhelming majority of trades today are electronic.
# 5. Buying on margin means borrowing money from a broker in order to buy more securities than can be purchased with one’s own money alone. By buying securities on a margin, an investor magnifies both the upside potential and the downside risk. If the equity in a margin account falls below the required maintenance level, the investor will get a margin call from the broker.
# 6. Short-selling is the practice of selling securities that the seller does not own. The short-seller borrows the securities sold through a broker and may be required to cover the short position at any time on demand. The cash proceeds of a short sale are kept in escrow by the broker, and the broker usually requires that the short-seller deposit additional cash or securities to serve as margin (collateral) for the short sale.
# 7. Securities trading is regulated by the Securities and Exchange Commission, by other government agencies, and through self-regulation of the exchanges. Many of the important regulations have to do with full disclosure of relevant information concerning the securities in question. Insider trading rules also prohibit traders from attempting to profit from inside information.
#
# ## Key Terms
# algorithmic trading
# ask price
# auction market
# bid–ask spread
# bid price
# blocks
# dark pools
# dealer markets
# electronic communication networks (ECNs)
# high-frequency trading
# initial public offering (IPO)
# inside information
# latency
# limit buy (sell) order
# margin
# NASDAQ Stock Market
# over-the-counter (OTC) market
# primary market
# private placement
# prospectus
# secondary market
# short sale
# specialist
# stock exchanges
# stop order
# underwriters

# %% [markdown]
# ## Assignment
# 1. A level **3** subscriber to the NASDAQ system may enter bid and ask prices.
# >NASDAQ has three levels of subscribers.
# Level 3 subscribers, are registered market makers. These are firms that make a market in securities, maintain inventories of securities, and post bid and ask prices at which they are willing to buy or sell shares. Level 3 subscribers can enter and change bid–ask quotes continually and have the fastest execution of trades. They profit from the spread between bid and ask prices.
# Level 2 subscribers receive all bid and ask quotes but cannot enter their own quotes. They can see which market makers are offering the best prices. These subscribers tend to be brokerage firms that execute trades for clients but do not actively deal in stocks for their own account.
# Level 1 subscribers receive only inside quotes (i.e., the best bid and ask prices) but do not see how many shares are being offered. These subscribers tend to be investors who are not actively buying or selling but want information on current prices.
#
# 2. **Continuous auction market** requires the greatest level of trading activity to be cost-effective.
# 3. Initial public offerings (IPOs) are usually **underpriced** relative to the levels at which their prices stabilize after they begin trading in the secondary market.
# 4. You purchased XYZ stock at \$50 per share. The stock is currently selling at \$65. Your gains could be protected by placing a **stop-loss order**
# 5. You sell short 300 shares of Microsoft that are currently selling at \$30 per share. You post the 50% margin required on the short sale. If you earn no interest on the funds in your margin account, what will be your rate of return after 1 year if Microsoft is selling at \$27? (Ignore any dividends.)
# $$\frac{300 \times ( 27 - 30 )} {300 \times 30 \times 50\%} = -20\%$$
# 6. You find that the bid and ask prices for a stock are \$10.85 and \$11.80, respectively. If you purchase or sell the stock, you must pay a flat commission of 25 dollars. If you buy 100 shares of the stock and immediately sell them, what is your total implied and actual transaction cost in dollars?
# $$(11.80 - 10.85)  \times 100 + \mathbf{2 \times}25 = 145 $$
# 7. You short-sell 200 shares of Tuckerton Trading Co., now selling for 56 per share. What is your maximum possible gain, ignoring transactions cost?
# $$200 \times 56 = 11200$$
# 8. An investor puts up \$15,000 but borrows an equal amount of money from his broker to double the amount invested to \$30,000. The broker charges 5% on the loan. The stock was originally purchased at \$20 per share, and in 1 year the investor sells the stock for \$22. The investor's rate of return was
# $$\frac{30000 \div 20 \times (22- 20) - 15000 \times 5\%} {15000} = 15\%$$
# 9. ...
# 10. The commission structure on a stock purchase is \$65 plus \$0.04 per share. If you purchase eight round lots of a stock selling for 194 bucks, what is your commission?
# $$8 \times 100 \times 0.04 + 65 = 97$$
